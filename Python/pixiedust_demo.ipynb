# %%
# !pip install pixiedust
import pixiedust
# Out:
# ...
#      |████████████████████████████████| 204kB 4.8MB/s
# ...
#      |████████████████████████████████| 798kB 40.3MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/25/fa/a5/09c1e8f4c91b34c5f7f4ac6e41be81dd0667030a2372546a8d
# ...
#   Stored in directory: /root/.cache/pip/wheels/c0/47/fb/8a64f89aecfe0059830479308ad42d62e898a3e3cefdf6ba28
# Successfully built pixiedust mpld3
# ...
# Pixiedust database opened successfully
# Table VERSION_TRACKER created successfully
# Table METRICS_TRACKER created successfully
#
# Share anonymous install statistics? (opt-out instructions)
#
# PixieDust will record metadata on its environment the next time the package is installed or updated. The data is anonymized and aggregated to help plan for future releases, and records only the following values:
#
# {
#    "data_sent": currentDate,
#    "runtime": "python",
#    "application_version": currentPixiedustVersion,
#    "space_id": nonIdentifyingUniqueId,
#    "config": {
# ...

# %%
# load pre-curated datasets ready for analysis

pixiedust.sampleData()
# Out:
# <table class="table table-hover pd_save" style="font-size:small">
#   <thead>
#     <tr>
#       <th align="center" valign="middle">Id</th>
#       <th>Name</th>
#       <th>Topic</th>
#       <th>Publisher</th>
#     </tr>
#   </thead>
#   <tbody>
#
#
#     <tr>
#         <td>1</td>
#         <td>Car performance data</td>
#         <td>Transportation</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>2</td>
#         <td>Sample retail sales transactions, January 2009</td>
#         <td>Economy & Business</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>3</td>
#         <td>Total population by country</td>
#         <td>Society</td>
#         <td>IBM Cloud Data Services</td>
#     </tr>
#
#
#
#     <tr>
#         <td>4</td>
#         <td>GoSales Transactions for Naive Bayes Model</td>
#         <td>Leisure</td>
#         <td>IBM</td>
#     </tr>
#
#
#
#     <tr>
#         <td>5</td>
# ...

# %%
# use pixiedust to download compressed files (ZIP or GZ) and load them into Spark or pandas Dataframes.

london_info = pixiedust.sampleData("https://files.datapress.com/london/dataset/london-borough-profiles/2015-09-24T15:50:01/London-borough-profiles.zip")
# Out:
# ...
# Extracting first item in zip file...
# File extracted: london-borough-profiles.csv
# Downloaded 948147 bytes
# Creating pandas DataFrame for 'https://files.datapress.com/london/dataset/london-borough-profiles/2015-09-24T15:50:01/London-borough-profiles.zip'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'https://files.datapress.com/london/dataset/london-borough-profiles/2015-09-24T15:50:01/London-borough-profiles.zip'

# %%
# explore the 'display' function!

display(london_info)
# Out:
# <script>
#     //Marker 9ff660fb
#     setTimeout(function(){
#         var cells=IPython.notebook.get_cells().filter(function(cell){
#             if(!cell.output_area || !cell.output_area.outputs){
#                 return false;
#             }
#             return cell.output_area.outputs.filter(function(output){
#                 if (output.output_type==="display_data"&&output.data&&output.data["text/html"]){
#                     return output.data["text/html"].includes("//Marker 9ff660fb")
#                 }
#                 return false;
#             }).length > 0;
#         });
#         if(cells.length>0){
#             var cell=cells[0];
#             var cellId=cell.cell_id;
#             var cellMetadata=cell._metadata.pixiedust;
#             var old_msg_id = cell.last_msg_id;
#             if (old_msg_id) {
#                 cell.kernel.clear_callbacks_for_msg(old_msg_id);
#             }
#             function getCellWidth(){
#                 try{
# ...

# %%
cars = pixiedust.sampleData(1, forcePandas=True)
display(cars)
# Out:
# ...
# Downloaded 20954 bytes
# Creating pandas DataFrame for 'Car performance data'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'Car performance data'
# <script>
#     //Marker b49ba445
#     setTimeout(function(){
#         var cells=IPython.notebook.get_cells().filter(function(cell){
#             if(!cell.output_area || !cell.output_area.outputs){
#                 return false;
#             }
#             return cell.output_area.outputs.filter(function(output){
#                 if (output.output_type==="display_data"&&output.data&&output.data["text/html"]){
#                     return output.data["text/html"].includes("//Marker b49ba445")
#                 }
#                 return false;
#             }).length > 0;
#         });
#         if(cells.length>0){
#             var cell=cells[0];
#             var cellId=cell.cell_id;
#             var cellMetadata=cell._metadata.pixiedust;
#             var old_msg_id = cell.last_msg_id;
# ...

# %%
homes = pixiedust.sampleData(6, forcePandas=True)
display(homes)
# Out:
# ...
# Downloaded 999888 bytes
# Creating pandas DataFrame for 'Million dollar home sales in Massachusetts, USA Feb 2017 through Jan 2018'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'Million dollar home sales in Massachusetts, USA Feb 2017 through Jan 2018'
# <script>
#     //Marker 4f6e48fd
#     setTimeout(function(){
#         var cells=IPython.notebook.get_cells().filter(function(cell){
#             if(!cell.output_area || !cell.output_area.outputs){
#                 return false;
#             }
#             return cell.output_area.outputs.filter(function(output){
#                 if (output.output_type==="display_data"&&output.data&&output.data["text/html"]){
#                     return output.data["text/html"].includes("//Marker 4f6e48fd")
#                 }
#                 return false;
#             }).length > 0;
#         });
#         if(cells.length>0){
#             var cell=cells[0];
# ...

# %% [markdown]
# pixiedust package could be successfully downloaded to colab, and we managed to access sample datasets. But an important function "display" fails. Sad news TAT
