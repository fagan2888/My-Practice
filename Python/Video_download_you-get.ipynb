# %% [markdown]
# ## `you-get` command
# [You-Get](https://pypi.org/project/you-get/) is a tiny command-line utility to download media contents (videos, audios, images) from the Web, in case there is no other handy way to do it.
#
# snytax:
# > you-get + url

# %%
# !pip3 install you-get

# %%
# !you-get https://v.youku.com/v_show/id_XNDU1NDc4Mzk5Ng==.html?spm=a2h0k.11417342.soresults.dtitle
# Out:
# site:                ä¼˜é…· (Youku)
# title:               2.21è¯­æ–‡å››å¹´çº§ä¸‹å†Œã€Š5.ç�¥ç�€ã€‹ç¬¬äºŒè¯¾æ—¶
# stream:
#     - format:        mp4hd3v2
#       container:     mp4
#       video-profile: 1080P
#       size:          65.2 MiB (68321907 bytes)
#       m3u8_url:      http://pl-ali.youku.com/playlist/m3u8?vid=XNDU1NDc4Mzk5Ng&type=hd3&ups_client_netip=47e817c5&utid=fsrcFi10VEACAUfoF8WA73IX&ccode=0519&psid=3438ae77934cfefb19efc347a8d38c88&duration=958&expire=18000&drm_type=1&drm_device=0&ups_ts=1582685314&onOff=0&encr=0&ups_key=7aceda0ee46be739fb43b1a353c78011
#     # download-with: you-get --format=mp4hd3v2 [URL]
#
# ...
#
#  0.0% (  0.0/ 65.2MB) â”œâ”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”¤[1/7]
#  0.4% (  0.2/ 65.2MB) â”œâ”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”¤[1/7]  440 kB/s
# ...
